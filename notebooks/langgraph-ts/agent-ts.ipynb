// %%
import * as path from "path";
import * as fs from "fs";
import * as dotenv from "dotenv";

// Load .env from cwd or project root (when run from notebooks/langgraph-ts/)
const envPath = path.resolve(process.cwd(), ".env");
const rootEnvPath = path.resolve(process.cwd(), "../../.env");
dotenv.config({ path: fs.existsSync(envPath) ? envPath : rootEnvPath });
// Out:
// [dotenv@17.3.1] injecting env (8) from .env -- tip: 🤖 agentic secret storage: https://dotenvx.com/as2
// {
//   parsed: {
//     OPENAI_API_KEY: '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',
//     LANGCHAIN_TRACING_V2: 'true',
//     LANGCHAIN_API_KEY: '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',
//     LANGCHAIN_PROJECT: 'nutriguide-ai-dev',
//     PORT: '3001',
//     AGENT_URL: 'http://localhost:8000',
//     AGENT_PORT: '8000',
//     CHROMA_URL: 'http://localhost:8001'
//   }
// }

// %%
// LLM Initialization
// Set your OpenAI API key in your environment or .env file
const OPENAI_API_KEY = process.env.OPENAI_API_KEY;
if (!OPENAI_API_KEY) {
  throw new Error("OPENAI_API_KEY is not set in the environment.");
}
// Out:
// 5:13 - Cannot find name 'Error'.
